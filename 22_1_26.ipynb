# %% [markdown]
# <a href="https://colab.research.google.com/github/MuskanTiwari12/90-days-aiml/blob/main/22_1_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# traffic light by condition sentence used

# %%
color= input("enter the color:")
if color=="red":
  print("stop now!")
elif color=="yellow":
  print("get ready!")
elif color=="green":
  print("goooo!")
else:
  print("wrong input")
# Out:
# enter the color:happy
# wrong input

# %% [markdown]
# age system

# %%
age=int(input("enter ur age"))
if age<13:
  print("childeren")
elif age>=13 and age<20:
  print("teenager")
elif age>=20 and age<40:
  print("adult")
else:
  print("senior citizen")
# Out:
# enter ur age12
# childeren

# %%
username="admin"
passward="1234me"
u=input("enter ur username:")
p=input("enter ur passward:")
if(u==username and p==passward):
  print("login successed")
elif(u!=username or p!=passward):
  print("login fail try again...")
  u=input("enter ur username:")
  p=input("enter ur passward:")
else:
  print("opps lock ur account")
# Out:
# enter ur username:muskan
# enter ur passward:1111
# login fail try again...
# enter ur username:admin
# enter ur passward:1234me

# %%
#odd even
num=int(input("enter num:"))
if(num%2==0):
  print("even")
else:
  print("odd")
# Out:
# enter num:456481269
# odd

# %% [markdown]
# loops

# %%
i=1
while(i<6):
  print(i)
  i+=1
while(i>0):
  print(i)
  i-=1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# multiplication tabel

# %%
num=int(input("enter number:"))
i=1
while(i<=10):
  print(num,"muliply by",i,"is",num*i)
  i+=1;
# Out:
# enter number:5
# 5 muliply by 1 is 5
# 5 muliply by 2 is 10
# 5 muliply by 3 is 15
# 5 muliply by 4 is 20
# 5 muliply by 5 is 25
# 5 muliply by 6 is 30
# 5 muliply by 7 is 35
# 5 muliply by 8 is 40
# 5 muliply by 9 is 45
# 5 muliply by 10 is 50

# %%
word=input("enter word")
ans=0
for i in word:
  if(i=="a" or i=="e" or i=="i" or i=="o" or i=="u"):
    ans+=1
print("vowel count:", ans)
# Out:
# enter wordmuskanjiiiiiii
# vowel count: 9

# %%
#sum of first n natural number
