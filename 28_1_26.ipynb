# %% [markdown]
# <a href="https://colab.research.google.com/github/MuskanTiwari12/90-days-aiml/blob/main/28_1_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
open("names.txt", "w")
# Out:
# <_io.TextIOWrapper name='names.txt' mode='w' encoding='utf-8'>

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'names.txt', 'sample_data']

# %% [markdown]
# 1. Create a program that:
# 1. Opens a file "names.txt" in write mode
# 2. Writes 5 names (one per line) entered by the user
# 3. Then opens the same file in read mode and prints all names

# %%
file=open("names.txt","w")

for i in range(5):
  name=input("enter name")
  file.write(name + "\n")

file.close();

file=open("names.txt","r")
print(file.read())
file.close()
# Out:
# enter nameguddu
# enter namebappa
# enter namemusku
# enter namedabbu
# enter namepappu
# guddu
# bappa
# musku
# dabbu
# pappu

# %% [markdown]
#  Create a program that:
# 1. Opens a file "log.txt" in append mode
# 2. Adds a new log entry (like "Program run successfully")
# 3. Opens the file in read mode and prints all logs

# %%
log_name= open("log.txt","a")
log_name.write("Program run successfully")
log_name.close()

log_name=open("log.txt","r")
print(log_name.read())
log_name.close()
# Out:
# Program run successfully

# %% [markdown]
# Q3. Create a program that:
# 1. Has a list of numbers: [5, 10, 15, 20, 25]
# 2. Uses a list comprehension to create a new list with only numbers greater
# than 15
# 3. Prints the new list

# %%
lst=[5,10,15,20,25]
new_list=[num for num in lst if num>15]
print(new_list)
# Out:
# [20, 25]

# %% [markdown]
# Create a Python dictionary of 3 cities and their populations. Save it to
# .
# Q4
# "cities.json"
# 1. Then load the JSON and print each city and its population.
# 2. Ask the user for a new city & its population - update this info in the json
# file.

# %%
import json
dic={
    "Jaipur":85000000,
    "Bhopal":78900000,
    "Mumbai":120000000,
    "Delhi":100000000
}
with open("cities.json","w") as file:
  json.dump(dic,file)

with open("cities.json","r") as file:
  data=json.load(file)
  print(data)

# 2
new_city= input("enter city: ")
pop=input("eneter population :")

data[new_city]= pop
with open("cities.json", "w") as file:
  json.dump(data,file)

print("Updated data:", data);
# Out:
# {'Jaipur': 85000000, 'Bhopal': 78900000, 'Mumbai': 120000000, 'Delhi': 100000000}
# enter city: Delhi
# eneter population :455
# Updated data: {'Jaipur': 85000000, 'Bhopal': 78900000, 'Mumbai': 120000000, 'Delhi': '455'}

# %% [markdown]
# Write a program that tries to open in read mode. If the file does not
# exist, catch the exception and print "File not found!".
# Q5 "data.txt"

# %%
try:
  file=open("data.txt","r")
  content=file.read()
  print(content)
  file.close()
except:
  print("file not found ERROR!!!")
# Out:
# file not found ERROR!!!
